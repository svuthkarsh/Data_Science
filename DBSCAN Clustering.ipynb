# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

# %%
X=np.array([[1,3],[2,4],[5,7],[9,11],[6,8],[22,90]])

# %%
X
# Out:
# array([[ 1,  3],
#        [ 2,  4],
#        [ 5,  7],
#        [ 9, 11],
#        [ 6,  8],
#        [22, 90]])

# %%
#Steps
epslion
minimun data point
core point
border point
noise/outliers

# %%
plt.figure(figsize=(11,5))
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
cluster=DBSCAN(eps=3,min_samples=2).fit(X)

# %%
cluster.labels_
# Out:
# array([ 0,  0,  1, -1,  1, -1], dtype=int64)

# %%
df=pd.read_csv("Mall_Customers.csv")
df.head(4)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77

# %%
## Accessing specific row values

final=df[["Annual Income (k$)","Spending Score (1-100)"]] storing two column data into a single variable
# Out:
# (250, 2)

# %%
# extracting Data columns
X=df.loc[:,["Annual Income (k$)",
                 "Spending Score (1-100)"]].values

# %%
X.shape
# Out:
# (250, 2)

# %%
plt.figure(figsize=(12,6))
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
from sklearn.neighbors import NearestNeighbors # importing the library
neighb = NearestNeighbors(n_neighbors=2) # creating an object of the NearestNeighbors class
nbrs=neighb.fit(X) # fitting the data to the object
distances,indices=nbrs.kneighbors(X)

# %%
# Sort and plot the distances results
distances = np.sort(distances, axis = 0) # sorting the distances
distances = distances[:, 1] # taking the second column of the sorted distances
plt.rcParams['figure.figsize'] = (11,4) # setting the figure size
plt.plot(distances) # plotting the distances
plt.show() # showing the plot

# %%
clustering=DBSCAN(eps=10,min_samples=4).fit(X)

# %%
labels=clustering.labels_

# %%
# Plot the clusters
plt.scatter(X[:, 0], X[:,1], c = labels, cmap= "plasma") # plotting the clusters
plt.xlabel("Income") # X-axis label
plt.ylabel("Spending Score") # Y-axis label
plt.show() # showing the plot
